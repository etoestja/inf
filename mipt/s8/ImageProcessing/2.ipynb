# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import skimage
from pandas import DataFrame as df

# %%
check = np.random.rand(80,80)

plt.imshow(check, cmap='gray', interpolation='nearest')

# %%
check.shape
# Out:
# (80, 80)

# %%
row = check.reshape(-1)

# %%
df(row).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5af0779350>]], dtype=object)

# %%
row.mean()
# Out:
# 0.50617081436020295

# %%
row.std()
# Out:
# 0.28844629191815641

# %%
from skimage import data

# %%
plt.imshow(data.camera())

# %%
plt.imshow(data.camera()>50)

# %%
data.camera().mean()
# Out:
# 118.31400299072266

# %%
v = skimage.filters.threshold_otsu(data.camera())

# %%
plt.imshow(data.camera()<v)

# %%
c = data.camera()
row = c.reshape(-1)

# %%
#im = np.minimum(np.maximum(-data.camera()*1. - 170, 0),255)**10
#im = c + 0.8 * c * (np.max(c)-c)
im = c > 150
plt.imshow(im, cmap='gray')

# %%
df(row).hist(bins = 180)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5ae448a450>]], dtype=object)

# %%
cn = c
for i in range(10):
    cn = skimage.exposure.equalize_hist(cn)
plt.imshow(cn, cmap='gray')

# %%
plt.imshow(c, cmap='gray')

# %%
df(cn.reshape(-1)).hist(bins=80)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5adf1acd50>]], dtype=object)

# %%
df(c.reshape(-1)).hist(bins=80)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5ae43747d0>]], dtype=object)
